# %%
from envs.test.DLLs.pyexpat import features


# This is a sample Python script.

# Press Shift+F10 to execute it or replace it with your code.
# Press Double Shift to search everywhere for classes, files, tool windows, actions, and settings.


def print_hi(name):
    # Use a breakpoint in the code line below to debug your script.
    print(f'Hi, {name}')  # Press Ctrl+F8 to toggle the breakpoint.


# Press the green button in the gutter to run the script.
if __name__ == '__main__':
    print_hi('PyCharm')

# See PyCharm help at https://www.jetbrains.com/help/pycharm/
# Out:
# Hi, PyCharm

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\anjula\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anjula\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\anjula\anaconda3\lib\site-packages (from pandas) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\anjula\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\anjula\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
data = pd.read_csv('Cancer.csv')

# %%
data.head(10)
# Out:
#   Patient_ID  Month_of_Birth   Age     Sex    Occupation T_Stage N_Stage  \
# 0      A0012              12  68.0  Female      Teaching      T1      N1
# 1      A0013              12  50.0  Female       Medical      T2      N2
# 2      A0014              11  58.0  Female   Engineering      T3      N3
# 3      A0015               3  58.0  Female    Technology      T1      N1
# 4      A0016               1  47.0  Female    Multimedia      T2      N1
# 5      A0017               2  51.0  Female      Research      T1      N1
# 6      A0018               5  51.0  Female  House Person      T1      N1
# 7      A0019               4  40.0  Female     Reporting      T2      N1
# 8      A0020               6  40.0  Female   Development      T4      N3
# 9      A0021               4  69.0  Female  Construction      T4      N3
#
#   6th_Stage             Differentiated  Grade   A_Stage  Tumor_Size  \
# 0       IIA      Poorly differentiated      3  Regional         4.0
# 1      IIIA  Moderately differentiated      2  Regional        35.0
# 2      IIIC  Moderately differentiated      2  Regional        63.0
# 3       IIA      Poorly differentiated      3  Regional        18.0
# 4       IIB      Poorly differentiated      3  Regional        41.0
# 5       IIA  Moderately differentiated      2  Regional        20.0
# 6       IIA        Well differentiated      1  Regional         8.0
# 7       IIB  Moderately differentiated      2  Regional        30.0
# 8      IIIC      Poorly differentiated      3  Regional       103.0
# 9      IIIC        Well differentiated      1   Distant        32.0
#
#   Estrogen_Status Progesterone_Status  Regional_Node_Examined  \
# 0        Positive            Positive                    24.0
# 1        Positive            Positive                    14.0
# 2        Positive            Positive                    14.0
# 3        Positive            Positive                     2.0
# 4        Positive            Positive                     3.0
# 5        Positive            Positive                    18.0
# 6        Positive            Positive                    11.0
# 7        Positive            Positive                     9.0
# 8        Positive            Positive                    20.0
# 9        Positive            Positive                    21.0
#
#    Reginol_Node_Positive  Survival_Months Mortality_Status
# 0                      1               60            Alive
# 1                      5               62            Alive
# 2                      7               75            Alive
# 3                      1               84            Alive
# 4                      1               50            Alive
# 5                      2               89            Alive
# 6                      1               54            Alive
# 7                      1               14             Dead
# 8                     18               70            Alive
# 9                     12               92            Alive

# %%
list(data.columns)
# Out:
# ['Patient_ID',
#  'Month_of_Birth',
#  'Age',
#  'Sex',
#  'Occupation',
#  'T_Stage',
#  'N_Stage',
#  '6th_Stage',
#  'Differentiated',
#  'Grade',
#  'A_Stage',
#  'Tumor_Size',
#  'Estrogen_Status',
#  'Progesterone_Status',
#  'Regional_Node_Examined',
#  'Reginol_Node_Positive',
#  'Survival_Months',
#  'Mortality_Status']

# %%
data.shape
# Out:
# (4024, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Patient_ID              4024 non-null   object
#  1   Month_of_Birth          4024 non-null   int64
#  2   Age                     4015 non-null   float64
#  3   Sex                     4020 non-null   object
#  4   Occupation              43 non-null     object
#  5   T_Stage                 4024 non-null   object
#  6   N_Stage                 4024 non-null   object
#  7   6th_Stage               4024 non-null   object
#  8   Differentiated          4024 non-null   object
#  9   Grade                   4024 non-null   int64
#  10  A_Stage                 4024 non-null   object
#  11  Tumor_Size              4021 non-null   float64
#  12  Estrogen_Status         4024 non-null   object
#  13  Progesterone_Status     4024 non-null   object
#  14  Regional_Node_Examined  4023 non-null   float64
#  15  Reginol_Node_Positive   4024 non-null   int64
#  16  Survival_Months         4024 non-null   int64
#  17  Mortality_Status        4024 non-null   object
# dtypes: float64(3), int64(4), object(11)
# memory usage: 566.0+ KB

# %%
data.describe()
# Out:
#        Month_of_Birth          Age        Grade   Tumor_Size  \
# count     4024.000000  4015.000000  4024.000000  4021.000000
# mean         6.481362    54.107098     2.150596    30.419299
# std          3.475442    11.715528     0.638234    21.161080
# min          1.000000   -50.000000     1.000000   -75.000000
# 25%          3.000000    47.000000     2.000000    16.000000
# 50%          6.000000    54.000000     2.000000    25.000000
# 75%         10.000000    61.000000     3.000000    38.000000
# max         12.000000   502.000000     4.000000   140.000000
#
#        Regional_Node_Examined  Reginol_Node_Positive  Survival_Months
# count             4023.000000            4024.000000      4024.000000
# mean                14.373602               4.158052        71.472167
# std                  8.129293               5.109331        25.361855
# min                  1.000000               1.000000         1.000000
# 25%                  9.000000               1.000000        56.000000
# 50%                 14.000000               2.000000        73.000000
# 75%                 19.000000               5.000000        90.000000
# max                 61.000000              46.000000       760.000000

# %%
data.isnull().sum()/len(data)
# Out:
# Patient_ID                0.000000
# Month_of_Birth            0.000000
# Age                       0.002237
# Sex                       0.000994
# Occupation                0.989314
# T_Stage                   0.000000
# N_Stage                   0.000000
# 6th_Stage                 0.000000
# Differentiated            0.000000
# Grade                     0.000000
# A_Stage                   0.000000
# Tumor_Size                0.000746
# Estrogen_Status           0.000000
# Progesterone_Status       0.000000
# Regional_Node_Examined    0.000249
# Reginol_Node_Positive     0.000000
# Survival_Months           0.000000
# Mortality_Status          0.000000
# dtype: float64

# %%
data.drop(['Patient_ID', 'Sex', 'Occupation', 'Month_of_Birth'], axis=1, inplace=True)

# %%
data.isnull().sum()
# Out:
# Age                       9
# T_Stage                   0
# N_Stage                   0
# 6th_Stage                 0
# Differentiated            0
# Grade                     0
# A_Stage                   0
# Tumor_Size                3
# Estrogen_Status           0
# Progesterone_Status       0
# Regional_Node_Examined    1
# Reginol_Node_Positive     0
# Survival_Months           0
# Mortality_Status          0
# dtype: int64

# %%
columns_to_fill = ['Age', 'Tumor_Size', 'Regional_Node_Examined']
data[columns_to_fill] = data[columns_to_fill].fillna(data[columns_to_fill].mean())
data.isna().sum()/len(data)*100
# Out:
# Age                       0.0
# T_Stage                   0.0
# N_Stage                   0.0
# 6th_Stage                 0.0
# Differentiated            0.0
# Grade                     0.0
# A_Stage                   0.0
# Tumor_Size                0.0
# Estrogen_Status           0.0
# Progesterone_Status       0.0
# Regional_Node_Examined    0.0
# Reginol_Node_Positive     0.0
# Survival_Months           0.0
# Mortality_Status          0.0
# dtype: float64

# %%
print(data['T_Stage'].unique())
print(data['N_Stage'].unique())
print(data['6th_Stage'].unique())
print(data['Differentiated'].unique())
print(data['A_Stage'].unique())
print(data['Estrogen_Status'].unique())
print(data['Progesterone_Status'].unique())
print(data['Mortality_Status'].unique())
# Out:
# ['T1' 'T2' 'T3' 'T4']
# ['N1' 'N2' 'N3']
# ['IIA' 'IIIA' 'IIIC' 'IIB' 'IIIB']
# ['Poorly differentiated' 'Moderately differentiated' 'Well differentiated'
#  'Undifferentiated']
# ['Regional' 'Distant']
# ['Positive' 'Negative']
# ['Positive' 'Negative']
# ['Alive' 'Dead' 'ALIVE' 'DEAD' 'ALive' 'alive' 'dead']

# %%
data['Mortality_Status'] = data['Mortality_Status'].str.lower()

# %%
data['Mortality_Status'] = data['Mortality_Status'].map({'dead': 0, 'alive': 1})

data['T_Stage'] = data['T_Stage'].map({'T1': 0, 'T2': 1, 'T3': 2, 'T4': 3})

data['N_Stage'] = data['N_Stage'].map({'N1': 0, 'N2': 1, 'N3': 2})

data['6th_Stage'] = data['6th_Stage'].map({'IIA': 0, 'IIIA': 1,'IIIC':2, 'IIB': 3, 'IIIB': 4})

data['Differentiated'] = data['Differentiated'].map({'Poorly differentiated': 0, 'Moderately differentiated': 1, 'Well differentiated': 2, 'Undifferentiated': 3})

data['A_Stage'] = data['A_Stage'].map({'Regional': 0, 'Distant': 1})

data['Estrogen_Status'] = data['Estrogen_Status'].map({'Negative': 0, 'Positive': 1})

data['Progesterone_Status'] = data['Progesterone_Status'].map({'Negative': 0, 'Positive': 1})

# %%
data.describe().transpose()
# Out:
#                          count       mean        std   min   25%   50%   75%  \
# Age                     4024.0  54.107098  11.702416 -50.0  47.0  54.0  61.0
# T_Stage                 4024.0   0.784791   0.765531   0.0   0.0   1.0   1.0
# N_Stage                 4024.0   0.438370   0.693479   0.0   0.0   0.0   1.0
# 6th_Stage               4024.0   1.404573   1.245559   0.0   0.0   1.0   3.0
# Differentiated          4024.0   0.868290   0.642398   0.0   0.0   1.0   1.0
# Grade                   4024.0   2.150596   0.638234   1.0   2.0   2.0   3.0
# A_Stage                 4024.0   0.022863   0.149485   0.0   0.0   0.0   0.0
# Tumor_Size              4024.0  30.419299  21.153189 -75.0  16.0  25.0  38.0
# Estrogen_Status         4024.0   0.933151   0.249791   0.0   1.0   1.0   1.0
# Progesterone_Status     4024.0   0.826541   0.378691   0.0   1.0   1.0   1.0
# Regional_Node_Examined  4024.0  14.373602   8.128282   1.0   9.0  14.0  19.0
# Reginol_Node_Positive   4024.0   4.158052   5.109331   1.0   1.0   2.0   5.0
# Survival_Months         4024.0  71.472167  25.361855   1.0  56.0  73.0  90.0
# Mortality_Status        4024.0   0.846918   0.360111   0.0   1.0   1.0   1.0
#
#                           max
# Age                     502.0
# T_Stage                   3.0
# N_Stage                   2.0
# 6th_Stage                 4.0
# Differentiated            3.0
# Grade                     4.0
# A_Stage                   1.0
# Tumor_Size              140.0
# Estrogen_Status           1.0
# Progesterone_Status       1.0
# Regional_Node_Examined   61.0
# Reginol_Node_Positive    46.0
# Survival_Months         760.0
# Mortality_Status          1.0

# %%
# !pip install plotly.express
# Out:
# Requirement already satisfied: plotly.express in c:\users\anjula\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: scipy>=0.18 in c:\users\anjula\anaconda3\lib\site-packages (from plotly.express) (1.9.1)
# Requirement already satisfied: numpy>=1.11 in c:\users\anjula\anaconda3\lib\site-packages (from plotly.express) (1.21.5)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\anjula\anaconda3\lib\site-packages (from plotly.express) (1.4.4)
# Requirement already satisfied: patsy>=0.5 in c:\users\anjula\anaconda3\lib\site-packages (from plotly.express) (0.5.2)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\anjula\anaconda3\lib\site-packages (from plotly.express) (5.9.0)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\anjula\anaconda3\lib\site-packages (from plotly.express) (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\anjula\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\anjula\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly.express) (2022.1)
# Requirement already satisfied: six in c:\users\anjula\anaconda3\lib\site-packages (from patsy>=0.5->plotly.express) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\anjula\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly.express) (8.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\anjula\anaconda3\lib\site-packages (from statsmodels>=0.9.0->plotly.express) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\anjula\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels>=0.9.0->plotly.express) (3.0.9)

# %%
import plotly.express as px

age_fig = px.box(data, x='Age', title='Detecting Outliers of Age')
age_fig.show()
# Out:
# <div>                            <div id="853c862a-dd3c-4a1b-b491-017b5f5d0a73" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("853c862a-dd3c-4a1b-b491-017b5f5d0a73")) {                    Plotly.newPlot(                        "853c862a-dd3c-4a1b-b491-017b5f5d0a73",                        [{"alignmentgroup":"True","hovertemplate":"Age=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[68.0,50.0,58.0,58.0,47.0,51.0,51.0,40.0,40.0,69.0,68.0,46.0,65.0,48.0,62.0,61.0,56.0,43.0,48.0,60.0,48.0,57.0,55.0,48.0,62.0,63.0,48.0,46.0,57.0,66.0,47.0,53.0,59.0,60.0,46.0,51.0,54.0,51.0,49.0,51.0,57.0,64.0,62.0,53.0,55.0,66.0,42.0,62.0,54.10709838107098,69.0,37.0,69.0,54.10709838107098,63.0,57.0,55.0,62.0,50.0,50.0,55.0,56.0,51.0,42.0,59.0,67.0,46.0,31.0,40.0,58.0,52.0,54.10709838107098,64.0,31.0,66.0,67.0,56.0,66.0,42.0,51.0,68.0,53.0,67.0,66.0,53.0,51.0,46.0,48.0,52.0,55.0,65.0,53.0,33.0,63.0,45.0,59.0,60.0,50.0,61.0,50.0,68.0,38.0,47.0,39.0,57.0,52.0,60.0,54.0,68.0,38.0,63.0,61.0,37.0,46.0,45.0,54.0,53.0,50.0,69.0,48.0,53.0,67.0,43.0,50.0,59.0,53.0,62.0,39.0,59.0,56.0,45.0,60.0,50.0,58.0,50.0,55.0,37.0,46.0,65.0,61.0,52.0,54.0,36.0,180.0,62.0,54.0,61.0,46.0,38.0,66.0,59.0,38.0,67.0,60.0,61.0,67.0,69.0,47.0,39.0,53.0,55.0,59.0,53.0,59.0,57.0,61.0,68.0,54.0,37.0,48.0,53.0,69.0,63.0,49.0,63.0,60.0,41.0,59.0,43.0,52.0,61.0,60.0,61.0,63.0,48.0,51.0,66.0,68.0,58.0,62.0,46.0,58.0,60.0,62.0,53.0,42.0,63.0,55.0,50.0,52.0,47.0,55.0,60.0,66.0,50.0,64.0,67.0,56.0,60.0,56.0,48.0,44.0,37.0,-50.0,63.0,54.0,63.0,44.0,68.0,64.0,50.0,55.0,66.0,46.0,43.0,43.0,43.0,59.0,55.0,61.0,66.0,55.0,65.0,69.0,59.0,63.0,68.0,48.0,61.0,43.0,44.0,47.0,52.0,69.0,39.0,43.0,64.0,66.0,45.0,37.0,50.0,40.0,52.0,54.10709838107098,32.0,65.0,67.0,57.0,63.0,42.0,57.0,42.0,46.0,47.0,67.0,67.0,65.0,65.0,33.0,64.0,66.0,34.0,55.0,47.0,58.0,38.0,57.0,65.0,52.0,67.0,57.0,61.0,45.0,50.0,50.0,53.0,54.0,58.0,56.0,68.0,41.0,61.0,65.0,69.0,43.0,47.0,67.0,45.0,65.0,53.0,67.0,43.0,47.0,48.0,62.0,68.0,57.0,40.0,56.0,52.0,40.0,51.0,67.0,54.0,56.0,48.0,57.0,47.0,54.0,41.0,65.0,58.0,38.0,38.0,60.0,58.0,63.0,53.0,43.0,60.0,60.0,47.0,48.0,59.0,56.0,53.0,48.0,52.0,61.0,66.0,45.0,52.0,67.0,40.0,50.0,65.0,55.0,47.0,49.0,53.0,53.0,44.0,54.0,51.0,46.0,47.0,68.0,50.0,67.0,47.0,68.0,55.0,47.0,56.0,51.0,41.0,67.0,58.0,67.0,63.0,69.0,59.0,54.10709838107098,65.0,48.0,39.0,55.0,50.0,39.0,49.0,58.0,34.0,49.0,52.0,62.0,55.0,57.0,40.0,52.0,63.0,57.0,40.0,55.0,42.0,52.0,39.0,53.0,47.0,37.0,63.0,54.10709838107098,50.0,56.0,56.0,52.0,38.0,57.0,56.0,54.10709838107098,54.0,69.0,62.0,63.0,46.0,47.0,55.0,40.0,47.0,52.0,65.0,63.0,57.0,45.0,62.0,54.0,65.0,64.0,47.0,63.0,66.0,69.0,48.0,60.0,61.0,61.0,43.0,49.0,63.0,61.0,61.0,69.0,66.0,39.0,52.0,49.0,55.0,62.0,42.0,50.0,52.0,38.0,39.0,57.0,62.0,55.0,47.0,68.0,50.0,42.0,54.10709838107098,42.0,46.0,50.0,62.0,58.0,53.0,46.0,38.0,40.0,60.0,63.0,49.0,57.0,48.0,46.0,61.0,61.0,53.0,53.0,42.0,57.0,56.0,48.0,59.0,57.0,56.0,64.0,50.0,40.0,40.0,52.0,59.0,53.0,54.0,61.0,54.10709838107098,41.0,57.0,40.0,63.0,62.0,62.0,42.0,47.0,53.0,64.0,51.0,56.0,50.0,66.0,56.0,46.0,66.0,57.0,55.0,32.0,58.0,63.0,48.0,64.0,44.0,57.0,61.0,502.0,45.0,52.0,67.0,45.0,63.0,56.0,46.0,53.0,62.0,47.0,39.0,33.0,56.0,55.0,69.0,58.0,42.0,58.0,51.0,64.0,62.0,52.0,43.0,65.0,59.0,62.0,51.0,57.0,46.0,40.0,49.0,46.0,40.0,49.0,61.0,56.0,50.0,55.0,60.0,34.0,51.0,53.0,58.0,61.0,48.0,63.0,56.0,66.0,64.0,49.0,56.0,67.0,42.0,47.0,60.0,43.0,42.0,60.0,52.0,63.0,60.0,61.0,58.0,52.0,64.0,68.0,47.0,51.0,53.0,63.0,50.0,45.0,68.0,46.0,54.0,65.0,51.0,45.0,45.0,57.0,35.0,54.0,68.0,58.0,48.0,59.0,47.0,52.0,46.0,34.0,34.0,36.0,40.0,38.0,61.0,37.0,60.0,38.0,56.0,49.0,65.0,61.0,69.0,53.0,61.0,47.0,62.0,6 ...

# %%
tumor_fig = px.box(data, x='Tumor_Size', title='Detecting Outliers of Tumor Size')
tumor_fig.show()
# Out:
# <div>                            <div id="caec1130-1490-47fc-afe3-8710ae1ab264" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caec1130-1490-47fc-afe3-8710ae1ab264")) {                    Plotly.newPlot(                        "caec1130-1490-47fc-afe3-8710ae1ab264",                        [{"alignmentgroup":"True","hovertemplate":"Tumor_Size=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[4.0,35.0,63.0,18.0,41.0,20.0,8.0,30.0,103.0,32.0,13.0,59.0,35.0,15.0,35.0,19.0,46.0,24.0,25.0,29.0,30.0,40.0,29.0,70.0,20.0,22.0,50.0,17.0,25.0,21.0,40.0,15.0,15.0,20.0,30.0,10.0,27.0,18.0,35.0,23.0,70.0,17.0,21.0,23.0,5.0,51.0,9.0,15.0,32.0,5.0,23.0,55.0,120.0,77.0,2.0,11.0,25.0,18.0,15.0,12.0,18.0,17.0,26.0,75.0,13.0,15.0,70.0,15.0,15.0,17.0,130.0,34.0,30.0,10.0,22.0,55.0,25.0,50.0,50.0,15.0,30.0,20.0,22.0,15.0,15.0,40.0,120.0,80.0,17.0,3.0,60.0,14.0,26.0,25.0,12.0,25.0,30.0,25.0,24.0,27.0,70.0,16.0,45.0,27.0,23.0,25.0,40.0,20.0,21.0,36.0,14.0,51.0,50.0,45.0,51.0,19.0,76.0,20.0,35.0,27.0,35.0,35.0,50.0,38.0,15.0,17.0,25.0,19.0,15.0,18.0,11.0,45.0,12.0,20.0,45.0,18.0,25.0,21.0,49.0,70.0,7.0,19.0,17.0,38.0,34.0,30.0,4.0,72.0,18.0,25.0,9.0,21.0,20.0,15.0,18.0,100.0,17.0,7.0,24.0,43.0,30.0,7.0,18.0,12.0,25.0,62.0,20.0,70.0,37.0,13.0,40.0,70.0,12.0,9.0,10.0,55.0,18.0,15.0,25.0,50.0,10.0,30.0,13.0,40.0,100.0,25.0,68.0,25.0,23.0,15.0,22.0,7.0,16.0,24.0,75.0,11.0,35.0,60.0,30.0,25.0,25.0,25.0,12.0,25.0,17.0,11.0,32.0,21.0,25.0,19.0,-75.0,52.0,9.0,17.0,35.0,85.0,50.0,51.0,18.0,75.0,72.0,35.0,12.0,23.0,16.0,16.0,57.0,50.0,17.0,32.0,21.0,11.0,40.0,15.0,17.0,14.0,60.0,55.0,120.0,11.0,39.0,23.0,28.0,37.0,40.0,9.0,8.0,28.0,15.0,17.0,50.0,48.0,30.0,68.0,110.0,23.0,12.0,13.0,40.0,30.0,9.0,22.0,30.0,12.0,10.0,25.0,16.0,65.0,22.0,17.0,60.0,22.0,35.0,18.0,34.0,6.0,105.0,100.0,20.0,57.0,10.0,17.0,25.0,21.0,45.0,50.0,35.0,38.0,16.0,140.0,25.0,18.0,18.0,34.0,65.0,13.0,20.0,29.0,10.0,62.0,50.0,29.0,15.0,15.0,42.0,130.0,21.0,51.0,30.0,35.0,31.0,14.0,15.0,60.0,20.0,22.0,80.0,15.0,100.0,30.0,8.0,15.0,80.0,30.0,25.0,24.0,35.0,12.0,45.0,25.0,35.0,28.0,17.0,15.0,32.0,15.0,60.0,90.0,11.0,37.0,21.0,2.0,70.0,8.0,22.0,40.0,13.0,32.0,5.0,18.0,52.0,31.0,14.0,7.0,12.0,21.0,20.0,26.0,16.0,15.0,25.0,20.0,80.0,30.0,16.0,20.0,17.0,100.0,41.0,16.0,25.0,108.0,12.0,38.0,24.0,45.0,98.0,25.0,30.0,90.0,27.0,47.0,30.0,25.0,17.0,22.0,18.0,18.0,25.0,27.0,25.0,70.0,65.0,22.0,45.0,20.0,65.0,17.0,15.0,15.0,19.0,90.0,10.0,40.0,31.0,30.0,26.0,25.0,11.0,22.0,59.0,23.0,25.0,18.0,15.0,30.0,25.0,27.0,25.0,24.0,24.0,20.0,10.0,7.0,42.0,54.0,75.0,15.0,22.0,20.0,65.0,61.0,27.0,16.0,35.0,55.0,17.0,8.0,25.0,10.0,26.0,120.0,7.0,18.0,30.0,70.0,20.0,80.0,30.0,45.0,25.0,6.0,21.0,11.0,18.0,40.0,20.0,12.0,16.0,10.0,20.0,20.0,25.0,17.0,22.0,20.0,20.0,30.0,13.0,15.0,36.0,8.0,10.0,35.0,70.0,35.0,74.0,16.0,70.0,21.0,100.0,70.0,12.0,80.0,25.0,19.0,25.0,16.0,60.0,15.0,20.0,9.0,16.0,60.0,15.0,12.0,17.0,25.0,18.0,15.0,45.0,70.0,10.0,9.0,12.0,15.0,18.0,12.0,16.0,15.0,30.0,20.0,21.0,10.0,35.0,22.0,33.0,60.0,13.0,21.0,13.0,39.0,29.0,35.0,18.0,100.0,130.0,21.0,26.0,50.0,8.0,16.0,16.0,15.0,28.0,23.0,1.0,23.0,21.0,19.0,87.0,33.0,15.0,13.0,15.0,25.0,60.0,30.0,18.0,20.0,55.0,30.41929868191992,11.0,11.0,40.0,16.0,55.0,36.0,16.0,25.0,30.0,19.0,30.0,55.0,80.0,50.0,14.0,10.0,30.0,60.0,24.0,32.0,42.0,35.0,26.0,30.0,31.0,11.0,26.0,18.0,43.0,20.0,35.0,13.0,14.0,81.0,10.0,10.0,20.0,30.0,22.0,20.0,28.0,80.0,37.0,35.0,12.0,19.0,20.0,22.0,14.0,32.0,80.0,21.0,25.0,21.0,15.0,28.0,18.0,27.0,30.0,25.0,35.0,12.0,30.0,29.0,70.0,21.0,60.0,25.0,20.0,22.0,12.0,48.0,31.0,27.0,18.0,1.0,40.0,26.0,80.0,20.0,27.0,20.0,30.0,25.0,22.0,63.0,10.0,10.0,40.0,10.0,40.0,20.0,30.0,6.0,22.0,22.0,15.0,40.0,45.0,13.0,25.0,1 ...

# %%
Q1 = data['Age'].quantile(0.25)  # 25th percentile
Q3 = data['Age'].quantile(0.75)  # 75th percentile
IQR = Q3 - Q1

lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR

data = data[(data['Age'] >= lower_fence) & (data['Age'] <= upper_fence)]

age_fig = px.box(data, x='Age', title="Boxplot of Age (Detecting Outliers)")
age_fig.show()
# Out:
# <div>                            <div id="a3c09aa4-91f9-4ae8-815d-91533c95235a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a3c09aa4-91f9-4ae8-815d-91533c95235a")) {                    Plotly.newPlot(                        "a3c09aa4-91f9-4ae8-815d-91533c95235a",                        [{"alignmentgroup":"True","hovertemplate":"Age=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[68.0,50.0,58.0,58.0,47.0,51.0,51.0,40.0,40.0,69.0,68.0,46.0,65.0,48.0,62.0,61.0,56.0,43.0,48.0,60.0,48.0,57.0,55.0,48.0,62.0,63.0,48.0,46.0,57.0,66.0,47.0,53.0,59.0,60.0,46.0,51.0,54.0,51.0,49.0,51.0,57.0,64.0,62.0,53.0,55.0,66.0,42.0,62.0,54.10709838107098,69.0,37.0,69.0,54.10709838107098,63.0,57.0,55.0,62.0,50.0,50.0,55.0,56.0,51.0,42.0,59.0,67.0,46.0,31.0,40.0,58.0,52.0,54.10709838107098,64.0,31.0,66.0,67.0,56.0,66.0,42.0,51.0,68.0,53.0,67.0,66.0,53.0,51.0,46.0,48.0,52.0,55.0,65.0,53.0,33.0,63.0,45.0,59.0,60.0,50.0,61.0,50.0,68.0,38.0,47.0,39.0,57.0,52.0,60.0,54.0,68.0,38.0,63.0,61.0,37.0,46.0,45.0,54.0,53.0,50.0,69.0,48.0,53.0,67.0,43.0,50.0,59.0,53.0,62.0,39.0,59.0,56.0,45.0,60.0,50.0,58.0,50.0,55.0,37.0,46.0,65.0,61.0,52.0,54.0,36.0,62.0,54.0,61.0,46.0,38.0,66.0,59.0,38.0,67.0,60.0,61.0,67.0,69.0,47.0,39.0,53.0,55.0,59.0,53.0,59.0,57.0,61.0,68.0,54.0,37.0,48.0,53.0,69.0,63.0,49.0,63.0,60.0,41.0,59.0,43.0,52.0,61.0,60.0,61.0,63.0,48.0,51.0,66.0,68.0,58.0,62.0,46.0,58.0,60.0,62.0,53.0,42.0,63.0,55.0,50.0,52.0,47.0,55.0,60.0,66.0,50.0,64.0,67.0,56.0,60.0,56.0,48.0,44.0,37.0,63.0,54.0,63.0,44.0,68.0,64.0,50.0,55.0,66.0,46.0,43.0,43.0,43.0,59.0,55.0,61.0,66.0,55.0,65.0,69.0,59.0,63.0,68.0,48.0,61.0,43.0,44.0,47.0,52.0,69.0,39.0,43.0,64.0,66.0,45.0,37.0,50.0,40.0,52.0,54.10709838107098,32.0,65.0,67.0,57.0,63.0,42.0,57.0,42.0,46.0,47.0,67.0,67.0,65.0,65.0,33.0,64.0,66.0,34.0,55.0,47.0,58.0,38.0,57.0,65.0,52.0,67.0,57.0,61.0,45.0,50.0,50.0,53.0,54.0,58.0,56.0,68.0,41.0,61.0,65.0,69.0,43.0,47.0,67.0,45.0,65.0,53.0,67.0,43.0,47.0,48.0,62.0,68.0,57.0,40.0,56.0,52.0,40.0,51.0,67.0,54.0,56.0,48.0,57.0,47.0,54.0,41.0,65.0,58.0,38.0,38.0,60.0,58.0,63.0,53.0,43.0,60.0,60.0,47.0,48.0,59.0,56.0,53.0,48.0,52.0,61.0,66.0,45.0,52.0,67.0,40.0,50.0,65.0,55.0,47.0,49.0,53.0,53.0,44.0,54.0,51.0,46.0,47.0,68.0,50.0,67.0,47.0,68.0,55.0,47.0,56.0,51.0,41.0,67.0,58.0,67.0,63.0,69.0,59.0,54.10709838107098,65.0,48.0,39.0,55.0,50.0,39.0,49.0,58.0,34.0,49.0,52.0,62.0,55.0,57.0,40.0,52.0,63.0,57.0,40.0,55.0,42.0,52.0,39.0,53.0,47.0,37.0,63.0,54.10709838107098,50.0,56.0,56.0,52.0,38.0,57.0,56.0,54.10709838107098,54.0,69.0,62.0,63.0,46.0,47.0,55.0,40.0,47.0,52.0,65.0,63.0,57.0,45.0,62.0,54.0,65.0,64.0,47.0,63.0,66.0,69.0,48.0,60.0,61.0,61.0,43.0,49.0,63.0,61.0,61.0,69.0,66.0,39.0,52.0,49.0,55.0,62.0,42.0,50.0,52.0,38.0,39.0,57.0,62.0,55.0,47.0,68.0,50.0,42.0,54.10709838107098,42.0,46.0,50.0,62.0,58.0,53.0,46.0,38.0,40.0,60.0,63.0,49.0,57.0,48.0,46.0,61.0,61.0,53.0,53.0,42.0,57.0,56.0,48.0,59.0,57.0,56.0,64.0,50.0,40.0,40.0,52.0,59.0,53.0,54.0,61.0,54.10709838107098,41.0,57.0,40.0,63.0,62.0,62.0,42.0,47.0,53.0,64.0,51.0,56.0,50.0,66.0,56.0,46.0,66.0,57.0,55.0,32.0,58.0,63.0,48.0,64.0,44.0,57.0,61.0,45.0,52.0,67.0,45.0,63.0,56.0,46.0,53.0,62.0,47.0,39.0,33.0,56.0,55.0,69.0,58.0,42.0,58.0,51.0,64.0,62.0,52.0,43.0,65.0,59.0,62.0,51.0,57.0,46.0,40.0,49.0,46.0,40.0,49.0,61.0,56.0,50.0,55.0,60.0,34.0,51.0,53.0,58.0,61.0,48.0,63.0,56.0,66.0,64.0,49.0,56.0,67.0,42.0,47.0,60.0,43.0,42.0,60.0,52.0,63.0,60.0,61.0,58.0,52.0,64.0,68.0,47.0,51.0,53.0,63.0,50.0,45.0,68.0,46.0,54.0,65.0,51.0,45.0,45.0,57.0,35.0,54.0,68.0,58.0,48.0,59.0,47.0,52.0,46.0,34.0,34.0,36.0,40.0,38.0,61.0,37.0,60.0,38.0,56.0,49.0,65.0,61.0,69.0,53.0,61.0,47.0,62.0,62.0,41.0,41.0,48.0 ...

# %%
Q1 = data['Tumor_Size'].quantile(0.25)  # 25th percentile
Q3 = data['Tumor_Size'].quantile(0.75)  # 75th percentile
IQR = Q3 - Q1

lower_fence = Q1 - 1.5 * IQR
upper_fence = Q3 + 1.5 * IQR

data = data[(data['Tumor_Size'] >= lower_fence) & (data['Tumor_Size'] <= upper_fence)]

age_fig = px.box(data, x='Tumor_Size', title="Boxplot of Tumor_Size (Detecting Outliers)")
age_fig.show()
# Out:
# <div>                            <div id="93ed7636-409c-492c-b239-52361a2ab3bc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("93ed7636-409c-492c-b239-52361a2ab3bc")) {                    Plotly.newPlot(                        "93ed7636-409c-492c-b239-52361a2ab3bc",                        [{"alignmentgroup":"True","hovertemplate":"Tumor_Size=%{x}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"h","showlegend":false,"x":[4.0,35.0,63.0,18.0,41.0,20.0,8.0,30.0,32.0,13.0,59.0,35.0,15.0,35.0,19.0,46.0,24.0,25.0,29.0,30.0,40.0,29.0,70.0,20.0,22.0,50.0,17.0,25.0,21.0,40.0,15.0,15.0,20.0,30.0,10.0,27.0,18.0,35.0,23.0,70.0,17.0,21.0,23.0,5.0,51.0,9.0,15.0,32.0,5.0,23.0,55.0,2.0,11.0,25.0,18.0,15.0,12.0,18.0,17.0,26.0,13.0,15.0,70.0,15.0,15.0,17.0,34.0,30.0,10.0,22.0,55.0,25.0,50.0,50.0,15.0,30.0,20.0,22.0,15.0,15.0,40.0,17.0,3.0,60.0,14.0,26.0,25.0,12.0,25.0,30.0,25.0,24.0,27.0,70.0,16.0,45.0,27.0,23.0,25.0,40.0,20.0,21.0,36.0,14.0,51.0,50.0,45.0,51.0,19.0,20.0,35.0,27.0,35.0,35.0,50.0,38.0,15.0,17.0,25.0,19.0,15.0,18.0,11.0,45.0,12.0,20.0,45.0,18.0,25.0,21.0,49.0,70.0,7.0,19.0,38.0,34.0,30.0,4.0,18.0,25.0,9.0,21.0,20.0,15.0,18.0,17.0,7.0,24.0,43.0,30.0,7.0,18.0,12.0,25.0,62.0,20.0,70.0,37.0,13.0,40.0,70.0,12.0,9.0,10.0,55.0,18.0,15.0,25.0,50.0,10.0,30.0,13.0,40.0,25.0,68.0,25.0,23.0,15.0,22.0,7.0,16.0,24.0,11.0,35.0,60.0,30.0,25.0,25.0,25.0,12.0,25.0,17.0,11.0,32.0,21.0,25.0,19.0,52.0,17.0,35.0,50.0,51.0,18.0,35.0,12.0,23.0,16.0,16.0,57.0,50.0,17.0,32.0,21.0,11.0,40.0,15.0,17.0,14.0,60.0,55.0,11.0,39.0,23.0,28.0,37.0,40.0,9.0,8.0,28.0,15.0,17.0,50.0,48.0,30.0,68.0,23.0,12.0,13.0,40.0,30.0,9.0,22.0,30.0,12.0,10.0,25.0,16.0,65.0,22.0,17.0,60.0,22.0,35.0,18.0,34.0,6.0,20.0,57.0,10.0,17.0,25.0,21.0,45.0,50.0,35.0,38.0,16.0,25.0,18.0,18.0,34.0,65.0,13.0,20.0,29.0,10.0,62.0,50.0,29.0,15.0,15.0,42.0,21.0,51.0,30.0,35.0,31.0,14.0,15.0,60.0,20.0,22.0,15.0,30.0,8.0,15.0,30.0,25.0,24.0,35.0,12.0,45.0,25.0,35.0,28.0,17.0,15.0,32.0,15.0,60.0,11.0,37.0,21.0,2.0,70.0,8.0,22.0,40.0,13.0,32.0,5.0,18.0,52.0,31.0,14.0,7.0,12.0,21.0,20.0,26.0,16.0,15.0,25.0,20.0,30.0,16.0,20.0,17.0,41.0,16.0,25.0,12.0,38.0,24.0,45.0,25.0,30.0,27.0,47.0,30.0,25.0,17.0,22.0,18.0,18.0,25.0,27.0,25.0,70.0,65.0,22.0,45.0,20.0,65.0,17.0,15.0,15.0,19.0,10.0,40.0,31.0,30.0,26.0,25.0,11.0,22.0,59.0,23.0,25.0,18.0,15.0,30.0,25.0,27.0,25.0,24.0,24.0,20.0,10.0,7.0,42.0,54.0,15.0,22.0,20.0,65.0,61.0,27.0,16.0,35.0,55.0,17.0,8.0,25.0,10.0,26.0,7.0,18.0,30.0,70.0,20.0,30.0,45.0,25.0,6.0,21.0,11.0,18.0,40.0,20.0,12.0,16.0,10.0,20.0,20.0,25.0,17.0,22.0,20.0,20.0,30.0,13.0,15.0,36.0,8.0,10.0,35.0,70.0,35.0,16.0,70.0,21.0,70.0,12.0,25.0,19.0,25.0,16.0,60.0,15.0,20.0,9.0,16.0,60.0,15.0,12.0,17.0,25.0,18.0,15.0,45.0,70.0,10.0,9.0,12.0,15.0,18.0,12.0,16.0,15.0,30.0,20.0,21.0,10.0,35.0,22.0,33.0,60.0,13.0,21.0,13.0,39.0,35.0,18.0,21.0,26.0,50.0,8.0,16.0,16.0,15.0,28.0,23.0,1.0,23.0,21.0,19.0,33.0,15.0,13.0,15.0,25.0,60.0,30.0,18.0,20.0,55.0,30.41929868191992,11.0,11.0,40.0,16.0,55.0,36.0,16.0,25.0,30.0,19.0,30.0,55.0,50.0,14.0,10.0,30.0,60.0,24.0,32.0,42.0,35.0,26.0,30.0,31.0,11.0,26.0,18.0,43.0,20.0,35.0,13.0,14.0,10.0,10.0,20.0,30.0,22.0,20.0,28.0,37.0,35.0,12.0,19.0,20.0,22.0,14.0,32.0,21.0,25.0,21.0,15.0,28.0,18.0,27.0,30.0,25.0,35.0,12.0,30.0,29.0,70.0,21.0,60.0,25.0,20.0,22.0,12.0,48.0,31.0,27.0,18.0,1.0,40.0,26.0,20.0,27.0,20.0,30.0,25.0,22.0,63.0,10.0,10.0,40.0,10.0,40.0,20.0,30.0,6.0,22.0,22.0,15.0,40.0,45.0,13.0,25.0,11.0,58.0,30.0,23.0,9.0,32.0,35.0,15.0,15.0,21.0,51.0,15.0,60.0,30.41929868191992,51.0,25.0,30.0,11.0,40.0,5.0,35.0,38.0,30.0,25.0,25.0,27.0,25.0,18.0,40.0,40.0,15.0,20.0,23.0,34.0,16.0,18.0,50.0,45.0,18.0,23.0,25.0,32.0,30.0,30.0,30.0,18.0,24.0,70.0,28.0,20.0,35.0 ...

# %%
data.shape
# Out:
# (3799, 14)

# %%
data.to_csv('Mortality_Status_data.csv', index=False)

# %% [markdown]
# I want to check that patients survival  months also. so for that i don't need already dead patient. then i'll remove those dead patients and save another dataset for check survival months

# %%
data = data[data.Mortality_Status == 1]
data.to_csv('Survival_Months.csv', index=False)

# %%
print(data['Mortality_Status'].unique())
# Out:
# [1]

# %% [markdown]
# Now start to choose a model, what is the most suitable for get the mortality status. If some model can give + 90% accuracy we can choose it. if its not we need to hypertune the model. So in this case i hope to get 3 models call Logistic regression, KNN and Naive Bayes.

# %%
data = pd.read_csv('Mortality_Status_data.csv')

# %%
data.head(10)
# Out:
#     Age  T_Stage  N_Stage  6th_Stage  Differentiated  Grade  A_Stage  \
# 0  68.0        0        0          0               0      3        0
# 1  50.0        1        1          1               1      2        0
# 2  58.0        2        2          2               1      2        0
# 3  58.0        0        0          0               0      3        0
# 4  47.0        1        0          3               0      3        0
# 5  51.0        0        0          0               1      2        0
# 6  51.0        0        0          0               2      1        0
# 7  40.0        1        0          3               1      2        0
# 8  69.0        3        2          2               2      1        1
# 9  68.0        0        0          0               1      2        0
#
#    Tumor_Size  Estrogen_Status  Progesterone_Status  Regional_Node_Examined  \
# 0         4.0                1                    1                    24.0
# 1        35.0                1                    1                    14.0
# 2        63.0                1                    1                    14.0
# 3        18.0                1                    1                     2.0
# 4        41.0                1                    1                     3.0
# 5        20.0                1                    1                    18.0
# 6         8.0                1                    1                    11.0
# 7        30.0                1                    1                     9.0
# 8        32.0                1                    1                    21.0
# 9        13.0                1                    1                     9.0
#
#    Reginol_Node_Positive  Survival_Months  Mortality_Status
# 0                      1               60                 1
# 1                      5               62                 1
# 2                      7               75                 1
# 3                      1               84                 1
# 4                      1               50                 1
# 5                      2               89                 1
# 6                      1               54                 1
# 7                      1               14                 0
# 8                     12               92                 1
# 9                      1               64                 0

# %%
data.shape
# Out:
# (3799, 14)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3799 entries, 0 to 3798
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     3799 non-null   float64
#  1   T_Stage                 3799 non-null   int64
#  2   N_Stage                 3799 non-null   int64
#  3   6th_Stage               3799 non-null   int64
#  4   Differentiated          3799 non-null   int64
#  5   Grade                   3799 non-null   int64
#  6   A_Stage                 3799 non-null   int64
#  7   Tumor_Size              3799 non-null   float64
#  8   Estrogen_Status         3799 non-null   int64
#  9   Progesterone_Status     3799 non-null   int64
#  10  Regional_Node_Examined  3799 non-null   float64
#  11  Reginol_Node_Positive   3799 non-null   int64
#  12  Survival_Months         3799 non-null   int64
#  13  Mortality_Status        3799 non-null   int64
# dtypes: float64(3), int64(11)
# memory usage: 415.6 KB

# %%
features = ['Tumor_Size', 'N_Stage', '6th_Stage', 'Differentiated', 'Grade', 'A_Stage', 'Tumor_Size', 'Progesterone_Status', 'Estrogen_Status', 'Regional_Node_Examined', 'Reginol_Node_Positive']

x = data[features]
y = data['Mortality_Status']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %%
print('Whole data shape', data.shape)
print('Training data shape', x_train.shape)
print('Test data shape', x_test.shape)
# Out:
# Whole data shape (3799, 14)
# Training data shape (3039, 11)
# Test data shape (760, 11)

# %% [markdown]
# * Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logreg = LogisticRegression()

# %%
logreg.fit(x_train, y_train)
# Out:
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning:
#
# lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
# LogisticRegression()

# %%
y_pred_train = logreg.predict(x_train)

# %%
y_pred = logreg.predict(x_test)

# %%
Comparison_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})

# %%
Comparison_df
# Out:
#       Actual  Predicted
# 3210       0          1
# 2864       1          1
# 2241       1          1
# 1814       1          1
# 3537       1          1
# ...      ...        ...
# 429        1          1
# 3536       1          1
# 3248       0          1
# 3456       0          1
# 2120       1          1
#
# [760 rows x 2 columns]

# %%
from sklearn.metrics import accuracy_score

accuracy = accuracy_score(y_train, y_pred_train)

print ("Logistic regression training accuracy is: ", accuracy)
# Out:
# Logistic regression training accuracy is:  0.8571898650871997

# %%
accuracy = accuracy_score(y_test, y_pred)

print ("Logistic regression testing accuracy is: ", accuracy)
# Out:
# Logistic regression testing accuracy is:  0.8657894736842106

# %% [markdown]
# Classification Report for Logistic Regression

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.10      0.18       111
#            1       0.87      1.00      0.93       649
#
#     accuracy                           0.87       760
#    macro avg       0.86      0.55      0.55       760
# weighted avg       0.86      0.87      0.82       760

# %% [markdown]
# I used Logistic Regression model for get the Mortality Status and its accuracy is  87 %

# %% [markdown]
# * KNN Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=9)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred_knn = knn.predict(x_test)
print("KNN Test Accuracy:", accuracy_score(y_test, y_pred_knn))
# Out:
# KNN Test Accuracy: 0.8486842105263158
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27324\751168079.py in <module>
# ----> 1 print(classification_report(y_test, y_pred_knn))
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict, zero_division)
#    2108     """
#    2109
# -> 2110     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    2111
#    2112     if labels is None:
#
# ~\anaconda3\lib\site-packages\sklearn\metrics\_classification.py in _check_targets(y_true, y_pred)
#      82     y_pred : array or indicator matrix
#      83     """
# ---> 84     check_consistent_length(y_true, y_pred)
#      85     type_true = type_of_target(y_true)
#      86     type_pred = type_of_target(y_pred)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     330     uniques = np.unique(lengths)
#     331     if len(uniques) > 1:
# --> 332         raise ValueError(
#     333             "Found input variables with inconsistent numbers of samples: %r"
#     334             % [int(l) for l in lengths]
#
# ValueError: Found input variables with inconsistent numbers of samples: [760, 3039]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3799 entries, 0 to 3798
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     3799 non-null   float64
#  1   T_Stage                 3799 non-null   int64
#  2   N_Stage                 3799 non-null   int64
#  3   6th_Stage               3799 non-null   int64
#  4   Differentiated          3799 non-null   int64
#  5   Grade                   3799 non-null   int64
#  6   A_Stage                 3799 non-null   int64
#  7   Tumor_Size              3799 non-null   float64
#  8   Estrogen_Status         3799 non-null   int64
#  9   Progesterone_Status     3799 non-null   int64
#  10  Regional_Node_Examined  3799 non-null   float64
#  11  Reginol_Node_Positive   3799 non-null   int64
#  12  Survival_Months         3799 non-null   int64
#  13  Mortality_Status        3799 non-null   int64
# dtypes: float64(3), int64(11)
# memory usage: 415.6 KB

# %%
print(x.shape, y.shape)
# Out:
# (3799, 11) (3799,)

# %%
y = data['Mortality_Status']

# %%
print(y.shape)
# Out:
# (3799,)

# %%
df_clean  = data.dropna(subset=x.columns.tolist() + ['Mortality_Status'])
x = df_clean[x.columns]
y = df_clean['Mortality_Status']

# %%
print(x.shape, y.shape)
# Out:
# (3799, 11) (3799,)

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=9)

# %%
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=9)

# %%
y_pred_knn = knn.predict(x_test)
print("KNN Test Accuracy:", accuracy_score(y_test, y_pred_knn))
# Out:
# KNN Test Accuracy: 0.8539473684210527
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test, y_pred_knn))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.07      0.11       100
#            1       0.87      0.97      0.92       660
#
#     accuracy                           0.85       760
#    macro avg       0.58      0.52      0.52       760
# weighted avg       0.80      0.85      0.81       760

# %% [markdown]
# KNN model's Accuracy is 85 %

# %% [markdown]
# * Naive Bayes Model

# %%
from sklearn.naive_bayes import GaussianNB

# %%
nb = GaussianNB()
nb.fit(x_train, y_train)
y_pred_nb = nb.predict(x_test)
print("Naive Bayes Test Accuracy:", accuracy_score(y_test, y_pred_nb))
# Out:
# Naive Bayes Test Accuracy: 0.8026315789473685

# %%
print(classification_report(y_test, y_pred_nb))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.28      0.32      0.30       100
#            1       0.89      0.88      0.89       660
#
#     accuracy                           0.80       760
#    macro avg       0.59      0.60      0.59       760
# weighted avg       0.81      0.80      0.81       760

# %% [markdown]
# Naive Bayes Model's accuracy is 80 %

# %% [markdown]
# So i chosen Logistic regression model for Hyper parameter tunning

# %%
from sklearn.model_selection import GridSearchCV

# Using Hyperparameter Optimization using grid search for Logistic Regression as it's the best performing model
# Hyperparameter grid
param_grid = {
    'C': [0.01, 0.1, 1, 10],             # Regularization strength
    'penalty': ['l1', 'l2'],             # Penalty type
    'solver': ['liblinear', 'saga']      # Solvers supporting both penalties
}

# Find the best fitting model
lr_gscv = GridSearchCV(LogisticRegression(), param_grid, cv=5)

# Fit the test data to the optimized model
lr_gscv.fit(x, y)

print("Best LR Parameters:", lr_gscv.best_params_)
# Out:
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
# Best LR Parameters: {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning:
#
# The max_iter was reached which means the coef_ did not converge

# %%
y_pred_tuned_lr = lr_gscv.predict(x_test)
print("Optimized Logistic Regression Test Accuracy:", accuracy_score(y_test, y_pred_tuned_lr))
# Out:
# Optimized Logistic Regression Test Accuracy: 0.8657894736842106

# %% [markdown]
# Not that much change from that hyper parameter tunning

# %% [markdown]
# let's try KNN model hyperparameter tunning because it's somewhat equal than logistic regression's accuracy model

# %%
# Hyperparameter Optimization (KNN)
import numpy as np
param_grid = {
    'n_neighbors': np.arange(1, 25),
    'metric': ['euclidean', 'manhattan']
    }

# Find the best fitting model with pre defined K values
knn_gscv = GridSearchCV(KNeighborsClassifier(), param_grid, cv=5)

# Fit the test data to the optimized model
knn_gscv.fit(x_train,y_train)

print("Best KNN Parameters:", knn_gscv.best_params_)
# Out:
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# ...
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
# Best KNN Parameters: {'metric': 'manhattan', 'n_neighbors': 11}
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.

# %%
#Prediction using best model with the best accuracy
y_pred = knn_gscv.predict(x_test)
print("Best KNN Test Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Best KNN Test Accuracy: 0.8631578947368421
# C:\Users\Anjula\anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning:
#
# Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.

# %% [markdown]
# Logistic Regression is the best model for Get Mortality status

# %% [markdown]
# lets use ensemble learning like ensembling Logistic regression model amd KNN model

# %%
from sklearn.ensemble import VotingClassifier

base_learners=[('KNN', KNeighborsClassifier(n_neighbors=11, metric='manhattan')),
 ('LR', LogisticRegression(C=10, penalty='l1', solver='liblinear'))]

ensemble_learner = VotingClassifier(base_learners, voting='soft')

# %%
# Training voting ensemble model and getting Predictions
ensemble_learner.fit(x_train, y_train)
y_pred_ensemble_learner = ensemble_learner.predict(x_test)

# Checking the accuracy levels of ensemble model predictions
ensemble_learner_accuracy = accuracy_score(y_test, y_pred_ensemble_learner)
print ("The voting ensemble classifier accuracy is: ", ensemble_learner_accuracy)
# Out:
# The voting ensemble classifier accuracy is:  0.868421052631579

# %%
print("Ensemble Learner Classification Report:\n", classification_report(y_test, y_pred_ensemble_learner))
# Out:
# Ensemble Learner Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.04      0.07       100
#            1       0.87      0.99      0.93       660
#
#     accuracy                           0.87       760
#    macro avg       0.69      0.52      0.50       760
# weighted avg       0.82      0.87      0.82       760

# %%
data['Mortality_Status'].value_counts()
# Out:
# 1    3245
# 0     554
# Name: Mortality_Status, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(class_weight='balanced')

# %%
y_probs = model.predict_proba(x_test)[:, 1]
y_pred = (y_probs > 0.4).astype(int)
# Out:
# ---------------------------------------------------------------------------
# NotFittedError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_27324\1639466933.py in <module>
# ----> 1 y_probs = model.predict_proba(x_test)[:, 1]
#       2 y_pred = (y_probs > 0.4).astype(int)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     846             classes corresponds to that in the attribute :term:`classes_`.
#     847         """
# --> 848         check_is_fitted(self)
#     849         # Check data
#     850         X = self._validate_X_predict(X)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_is_fitted(estimator, attributes, msg, all_or_any)
#    1220
#    1221     if not fitted:
# -> 1222         raise NotFittedError(msg % {"name": type(estimator).__name__})
#    1223
#    1224
#
# NotFittedError: This RandomForestClassifier instance is not fitted yet. Call 'fit' with appropriate arguments before using this estimator.
